# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='

# %%
news_tables = {}
tickers = ['AMZN', 'TSLA', 'GOOG']

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

# %%
# Read one single day of headlines for 'AMZN' 
amzn = news_tables['AMZN']
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# Coronavirus Crisis Gives Less Room for Zoom to Boom
# May-05-20 07:17PM
# Amazon Worker at Staten Island Warehouse Dies From Covid-19
# 06:32PM
# U.S. Customs Agency Enlists Amazon, Pfizer, 3M in Fight Against Counterfeit Coronavirus Products
# 06:01PM
# Impossible Foods, Beyond Meat see spike in demand as coronavirus wreaks havoc on meat supply
# 05:34PM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['AMZN',
#   'May-05-20',
#   '07:17PM',
#   'Coronavirus Crisis Gives Less Room for Zoom to Boom'],
#  ['AMZN',
#   'May-05-20',
#   '06:32PM',
#   'Amazon Worker at Staten Island Warehouse Dies From Covid-19'],
#  ['AMZN',
#   'May-05-20',
#   '06:01PM',
#   'U.S. Customs Agency Enlists Amazon, Pfizer, 3M in Fight Against Counterfeit Coronavirus Products'],
#  ['AMZN',
#   'May-05-20',
#   '05:34PM',
#   'Impossible Foods, Beyond Meat see spike in demand as coronavirus wreaks havoc on meat supply'],
#  ['AMZN',
#   'May-05-20',
#   '05:30PM',
#   'Spotify CEO Expects Apple to Further Open Up After Complaint'],
#  ['AMZN',
#   'May-05-20',
#   '04:40PM',
#   'AWS Announces General Availability of UltraWarm for Amazon Elasticsearch Service'],
#  ['AMZN',
#   'May-05-20',
#   '04:09PM',
#   'Beyond Meat suspends 2020 forecast on COVID-19 concerns; posts sales beat'],
#  ['AMZN',
#   'May-05-20',
#   '04:04PM',
#   'These 10 S&P 500 companies increased sales faster than Amazon in a coronavirus-tainted quarter'],
#  ['AMZN',
#   'May-05-20',
#   '03:41PM',
#   'Schwabs plan to offer fractional shares starting in June is a shot across the bow at Robinhood, Stash'],
#  ['AMZN',
#   'May-05-20',
#   '03:25PM',
#   'Wayfair Soars to Record After Retailers Positive Forecast'],
#  ['AMZN',
#   'May-05-20',
#   '02:58PM',
#   '11 Best E-Commerce Stocks for Electrifying Returns'],
#  ['AMZN',
#   'May-05-20',
#   '02:54PM',
#   'Dont be like Warren Buffett  avoid value stocks for now'],
#  ['AMZN',
#   'May-05-20',
#   '01:35PM',
#   'Impossible Foods headed to 1,700 Kroger locations'],
#  ['AMZN',
#   'May-05-20',
#   '01:33PM',
#   "Here's How Warren Buffett Is Tackling the Retail Industry in 2020"],
#  ['AMZN',
#   'May-05-20',
#   '01:15PM',
#   'US STOCKS-Wall Street jumps as energy shares rise, lockdowns ease'],
#  ['AMZN',
#   'May-05-20',
#   '12:40PM',
#   'Hanesbrands CEO: Champion Online Sales Are at Black Friday Levels'],
#  ['AMZN',
#   'May-05-20',
#   '12:37PM',
#   'MEDIA-ICE partners with Amazon, 3M to identify counterfeit coronavirus gear - WSJ'],
#  ['AMZN', 'May-05-20', '12:30PM', 'Why Etsy Stock Popped Today'],
#  ['AMZN',
#   'May-05-20',
#   '11:54AM',
#   'Here is Why You Should Sell Amazon.com Now'],
#  ['AMZN',
#   'May-05-20',
#   '11:42AM',
#   'US STOCKS-Wall Street jumps as battered energy shares rise, lockdowns ease'],
#  ['AMZN',
#   'May-05-20',
#   '11:32AM',
#   'Service side of the U.S. economy crashes in April to recession levels, ISM shows'],
#  ['AMZN', 'May-05-20', '11:25AM', 'The Corona Effect, Part 3'],
#  ['AMZN',
#   'May-05-20',
#   '11:17AM',
#   'Microsoft Taps Coca-Cola to Challenge Amazon, Salesforce, and Slack'],
#  ['AMZN',
#   'May-05-20',
#   '11:05AM',
#   'CORRECTED-XPO Logistics jump 13% on cost-cutting, e-commerce growth'],
#  ['AMZN',
#   'May-05-20',
#   '11:00AM',
#   "Here's How Coronavirus Will Impact Amazon's Profit Growth"],
#  ['AMZN',
#   'May-05-20',
#   '10:45AM',
#   'E-Commerce Stock Q1 Earnings Due This Week: IAC, CVNA & More'],
#  ['AMZN',
#   'May-05-20',
#   '10:42AM',
#   'US STOCKS-Wall St jumps as battered energy shares rise, lockdowns ease'],
#  ['AMZN',
#   'May-05-20',
#   '10:15AM',
#   'Sell Cloud Stocks Salesforce.com and Workday, Analyst Says'],
#  ['AMZN',
#   'May-05-20',
#   '09:10AM',
#   'Facebook Eyes a Huge Opportunity in E-Commerce'],
#  ['AMZN',
#   'May-05-20',
#   '09:00AM',
#   'Prime Members Are Getting More Value From Amazon Than Ever'],
#  ['AMZN',
#   'May-05-20',
#   '07:46AM',
#   'The Twitter response to J.Crews filing for bankruptcy has been savage  but there is a point being made'],
#  ['AMZN', 'May-05-20', '07:43AM', 'PRESS DIGEST - Canada - May 5'],
#  ['AMZN',
#   'May-05-20',
#   '07:37AM',
#   'Better Buy: Plug Power vs. Brookfield Renewable Partners'],
#  ['AMZN',
#   'May-05-20',
#   '07:22AM',
#   'Free One-Day Shipping Is Costing Amazon a Fortune'],
#  ['AMZN',
#   'May-05-20',
#   '06:15AM',
#   'Disney Reports Earnings Today. Heres What to Expect.'],
#  ['AMZN',
#   'May-04-20',
#   '11:00PM',
#   'Amazon and eBay should be liable for faulty goods, says EU group'],
#  ['AMZN',
#   'May-04-20',
#   '07:51PM',
#   'GLOBAL MARKETS-Tech-led Wall St rebound set to lead Asia higher'],
#  ['AMZN',
#   'May-04-20',
#   '07:29PM',
#   'Amazon executive says he quit to protest firings of workers who spoke out'],
#  ['AMZN',
#   'May-04-20',
#   '06:13PM',
#   'J. Crew Is the First of Many\xa0Retail Casualties'],
#  ['AMZN', 'May-04-20', '05:40PM', 'The Worrisome State of Corporate Debt'],
#  ['AMZN', 'May-04-20', '05:00PM', 'Lets Make a Deal With Our Robot Overlords'],
#  ['AMZN',
#   'May-04-20',
#   '04:47PM',
#   'US STOCKS-Wall Street snaps 2-day slump on lift from tech titans'],
#  ['AMZN',
#   'May-04-20',
#   '04:25PM',
#   'US STOCKS-Wall St snaps two-day slump as tech titans give lift'],
#  ['AMZN',
#   'May-04-20',
#   '02:56PM',
#   'The Dow Is Dropping Because Tech Stocks Never Go Out of Style'],
#  ['AMZN',
#   'May-04-20',
#   '01:56PM',
#   'This year is lining up exactly like the 2000 dot-com bubble crash  stocks will drop 40% from here, former Goldman manager says'],
#  ['AMZN',
#   'May-04-20',
#   '01:40PM',
#   'Coronavirus: Amazon vice-president quits over virus firings'],
#  ['AMZN',
#   'May-04-20',
#   '01:30PM',
#   'Amazon plans to extend closure of French warehouses until May 8'],
#  ['AMZN',
#   'May-04-20',
#   '12:45PM',
#   '5 Tech Stocks With Enough Cash to Outlast the COVID-19 Crisis'],
#  ['AMZN',
#   'May-04-20',
#   '12:30PM',
#   'Is Shopify Getting Ready to Challenge Amazon?'],
#  ['AMZN',
#   'May-04-20',
#   '12:26PM',
#   'An Amazon executive quits over the companys firing of activist employees'],
#  ['AMZN',
#   'May-04-20',
#   '12:07PM',
#   "Belgium's Bpost cancels outlook over pandemic uncertainty"],
#  ['AMZN',
#   'May-04-20',
#   '11:45AM',
#   "France to Amazon: no you can't have state support"],
#  ['AMZN',
#   'May-04-20',
#   '11:38AM',
#   'Amazon (AMZN) Stock Still Has Room to Run, Says 5-Star Analyst in Hiking Price Target'],
#  ['AMZN', 'May-04-20', '11:19AM', '50 Top Stock Picks That Billionaires Love'],
#  ['AMZN',
#   'May-04-20',
#   '10:45AM',
#   'Could This Behind-the-Scenes Company Be a Market Beater?'],
#  ['AMZN',
#   'May-04-20',
#   '10:30AM',
#   'Amazon Crashes Post Q1: What Awaits for ETFs?'],
#  ['AMZN',
#   'May-04-20',
#   '10:24AM',
#   'Top ETF Stories of April Likely to Hit Headlines Again in May'],
#  ['AMZN',
#   'May-04-20',
#   '09:33AM',
#   'The Zacks Analyst Blog Highlights: Microsoft, Amazon, Alphabet and Facebook'],
#  ['AMZN',
#   'May-04-20',
#   '09:30AM',
#   'Amazon Is Showing No Signs of Slowing Down'],
#  ['AMZN', 'May-04-20', '09:13AM', 'Stock Market News for May 4, 2020'],
#  ['AMZN',
#   'May-04-20',
#   '09:06AM',
#   'Coronavirus Fallout: J.Crew Filed for Chapter 11 Bankruptcy Today'],
#  ['AMZN',
#   'May-04-20',
#   '08:48AM',
#   'Look Out Alibaba, JD.com Is Expanding Its Cloud and AI Presence'],
#  ['AMZN',
#   'May-04-20',
#   '08:43AM',
#   'Amazon web services VP resigns over whistleblower firings'],
#  ['AMZN',
#   'May-04-20',
#   '08:06AM',
#   "France rejects Amazon's request for unemployment schemes at six sites"],
#  ['AMZN',
#   'May-04-20',
#   '08:00AM',
#   "Is Amazon Stock A Buy Right Now? Here's What Earnings, Charts Show"],
#  ['AMZN',
#   'May-04-20',
#   '08:00AM',
#   'How This Top Mutual Fund Found Stocks That Defied The Covid-19 Downturn'],
#  ['AMZN',
#   'May-04-20',
#   '08:00AM',
#   "Buffett and a Potential Successor Reassure Shareholders on Berkshire's Future"],
#  ['AMZN',
#   'May-04-20',
#   '07:21AM',
#   'Ranking the FAANG Stocks From Cheapest to Most Expensive'],
#  ['AMZN',
#   'May-04-20',
#   '07:00AM',
#   'Coronavirus crisis fuels Brazil e-commerce shift as malls suffer'],
#  ['AMZN', 'May-04-20', '06:26AM', 'RPT-BUZZ-U.S. stocks weekly: Murky'],
#  ['AMZN',
#   'May-04-20',
#   '06:15AM',
#   '2 Stocks That Could Turn Your $1,200 Stimulus Check Into a Fortune'],
#  ['AMZN',
#   'May-04-20',
#   '06:01AM',
#   'A truncated recovery for the economy, but stocks will do better because bigger companies will thrive'],
#  ['AMZN', 'May-03-20', '08:17PM', 'PRESS DIGEST- British Business - May 4'],
#  ['AMZN',
#   'May-03-20',
#   '01:41PM',
#   'Amazons CEO tells investors you may want to take a seat, as he explains why the company will spend entirety of $4 billion profit'],
#  ['AMZN', 'May-03-20', '01:00PM', 'Is American Eagle Outfitters Stock a Buy?'],
#  ['AMZN',
#   'May-03-20',
#   '12:10PM',
#   'Walmart Wants Online Shoppers to Pay More For Faster Delivery'],
#  ['AMZN',
#   'May-03-20',
#   '10:39AM',
#   "COVID-19 Is Turning Amazon's Business Upside Down"],
#  ['AMZN',
#   'May-03-20',
#   '10:30AM',
#   'Amazons Jeff Bezos Called to Testify on Third-Party Sellers Data'],
#  ['AMZN',
#   'May-03-20',
#   '10:00AM',
#   '1 Under-the-Radar Stat Shows How the Coronavirus Pandemic Is Making Shopify Even Stronger'],
#  ['AMZN',
#   'May-03-20',
#   '08:45AM',
#   'Google Cloud and YouTube Help Protect Alphabet From a Coronavirus Disaster'],
#  ['AMZN',
#   'May-03-20',
#   '08:20AM',
#   'Earnings Miss: Amazon.com, Inc. Missed EPS By 18% And Analysts Are Revising Their Forecasts'],
#  ['AMZN',
#   'May-03-20',
#   '08:16AM',
#   'Could Oracle Solve Zoom Video Communications Biggest Problem?'],
#  ['AMZN',
#   'May-03-20',
#   '08:00AM',
#   'The Next Frontier of Shopping Will Be Livestreamed'],
#  ['AMZN',
#   'May-03-20',
#   '06:00AM',
#   'The 3 Best Warren Buffett Stocks to Buy Right Now'],
#  ['AMZN',
#   'May-03-20',
#   '03:04AM',
#   'Amazon Dips 8% on $4 Billion Virus Costs Amid Prospect For 2Q Loss'],
#  ['AMZN',
#   'May-02-20',
#   '03:39PM',
#   'Retiring in 10-20 years? Heres your best approach to stocks right now, says top U.S. financial adviser.'],
#  ['AMZN',
#   'May-02-20',
#   '01:00PM',
#   "Amazon's New NFL Deal Could Get Even Bigger Next Year"],
#  ['AMZN',
#   'May-02-20',
#   '12:52PM',
#   'Highlights From Palm Valley Capital Funds 2020 Investor Letter'],
#  ['AMZN', 'May-02-20', '12:49PM', '5 Top Coronavirus Stocks to Buy in May'],
#  ['AMZN',
#   'May-02-20',
#   '11:51AM',
#   'Coronavirus update: More than a million people have recovered; Trump pushes China conspiracy theory'],
#  ['AMZN',
#   'May-02-20',
#   '11:08AM',
#   'Amazon.com\xa0Has Four Flavors of Free Cash Flow. Which is Your Favorite?'],
#  ['AMZN',
#   'May-02-20',
#   '10:34AM',
#   'Most People Want to Bail Out the USPS, According to a New Poll'],
#  ['AMZN',
#   'May-02-20',
#   '10:17AM',
#   'Are investors driven by FOMO, or is a retest of the lows coming? Heres what Wall Street strategists are saying about the stock-market outlook'],
#  ['AMZN',
#   'May-02-20',
#   '09:16AM',
#   'Amazon will spend $4 billion or more on coronavirus response, potentially wiping out Q2 profit'],
#  ['AMZN',
#   'May-02-20',
#   '09:15AM',
#   "How Amazon Web Services Stacked Up Against Microsoft's Azure"],
#  ['AMZN', 'May-02-20', '09:15AM', 'Market Slides More Than 2% to Begin May'],
#  ['AMZN',
#   'May-02-20',
#   '09:14AM',
#   'Netflix may have edge on competition as coronavirus keeps people looking for new shows'],
#  ['AMZN',
#   'May-02-20',
#   '09:05AM',
#   'Why Charter Communications could be in same exclusive club as Amazon and Netflix'],
#  ['AMZN',
#   'May-02-20',
#   '08:16AM',
#   'Stock Market Today With Jim Cramer: Clorox Stock'],
#  ['AMZN',
#   'May-02-20',
#   '07:18AM',
#   'Here are Fridays biggest stock-market losers, driven lower by disappointing earnings and a shrinking manufacturing sector'],
#  ['TSLA',
#   'May-06-20',
#   '01:00AM',
#   'GM investors want to know how much more coronavirus pain remains'],
#  ['TSLA',
#   'May-05-20',
#   '04:19PM',
#   'Stock Market Today With Jim Cramer: Buy Tesla Stock Now'],
#  ['TSLA',
#   'May-05-20',
#   '03:59PM',
#   'Trading Tesla Stock After Elon Musk Reaches Windfall'],
#  ['TSLA',
#   'May-05-20',
#   '03:41PM',
#   'Schwabs plan to offer fractional shares starting in June is a shot across the bow at Robinhood, Stash'],
#  ['TSLA',
#   'May-05-20',
#   '03:15PM',
#   'Q1 Scorecard and Analyst Research Reports for Alibaba, Verizon, Coca-Cola & Others'],
#  ['TSLA',
#   'May-05-20',
#   '12:44PM',
#   'As British car sales collapse, Tesla Model 3 becomes top-selling U.K. vehicle for April'],
#  ['TSLA',
#   'May-05-20',
#   '11:57AM',
#   "Is Tesla Stock A Buy Right Now? Here's What Earnings, Charts Show"],
#  ['TSLA',
#   'May-05-20',
#   '11:53AM',
#   "6 Reasons Why Morgan Stanley Says Tesla's Next Gigafactory Location Is Texas"],
#  ['TSLA',
#   'May-05-20',
#   '11:45AM',
#   'Dow Jones Surges 400 Points On Easing Lockdowns; Microsoft Breaks Out Above New Buy Point'],
#  ['TSLA',
#   'May-05-20',
#   '11:34AM',
#   'This could be the end of the stock market as we know it, but that may not be a bad thing, strategist suggests'],
#  ['TSLA',
#   'May-05-20',
#   '10:30AM',
#   'Elon Musk Is Selling Two Bel Air Mansions for $40 Million After Pledging to Own No House'],
#  ['TSLA',
#   'May-05-20',
#   '09:54AM',
#   "Elon Musk Hits Pay Dirt as Tesla's Market Value Surpasses Windfall Trigger"],
#  ['TSLA',
#   'May-05-20',
#   '09:48AM',
#   "Auto Stocks' Earnings Roster for May 6: GM, GPC, CNHI & BWA"],
#  ['TSLA',
#   'May-05-20',
#   '08:10AM',
#   'Tesla stock rise appears to qualify CEO Musk for $700 million payday'],
#  ['TSLA',
#   'May-05-20',
#   '06:47AM',
#   'Tesla stock rise may qualify Musk for $700mln payday'],
#  ['TSLA',
#   'May-04-20',
#   '11:29PM',
#   "Elon Musk Confirms Grimes Has Given Birth: 'Mom & Baby All Good'"],
#  ['TSLA',
#   'May-04-20',
#   '09:33PM',
#   "2 Of Elon Musk's Houses May Actually Be For Sale: Here's Why"],
#  ['TSLA',
#   'May-04-20',
#   '06:01PM',
#   "Tesla's Elon Musk Puts Two Homes on Market"],
#  ['TSLA',
#   'May-04-20',
#   '04:09PM',
#   "Dow Jones Closes Higher Despite Trump's Coronavirus Claims, As Energy, Techs Rally"],
#  ['TSLA',
#   'May-04-20',
#   '02:50PM',
#   "Elon Musk Says He's Getting Rid of Most of His Possessions"],
#  ['TSLA',
#   'May-04-20',
#   '02:25PM',
#   "Tesla, Inc. Just Beat Earnings Expectations: Here's What Analysts Think Will Happen Next"],
#  ['TSLA', 'May-04-20', '01:26PM', 'Why Tesla Stock Jumped Monday'],
#  ['TSLA',
#   'May-04-20',
#   '11:37AM',
#   'Auto Stock Roundup: TSLA, HOG & CMI Top Q1 Earnings Estimates, F Incurs Loss'],
#  ['TSLA', 'May-04-20', '11:19AM', '50 Top Stock Picks That Billionaires Love'],
#  ['TSLA',
#   'May-04-20',
#   '09:34AM',
#   'Just after Elon Musk denounced coronavirus lockdowns as infringements of freedom, research shows Britons are too scared to leave their homes anyway'],
#  ['TSLA',
#   'May-04-20',
#   '09:19AM',
#   'The Zacks Analyst Blog Highlights: Tesla, Cisco, Comcast, Qualcomm and Micron'],
#  ['TSLA',
#   'May-04-20',
#   '06:30AM',
#   'Elon Musk Said Teslas Stock Price Is Too High. What History Says Happens Next.'],
#  ['TSLA',
#   'May-03-20',
#   '08:44PM',
#   'Were Hedge Funds (They Arent All Short) Right About Tesla Inc. (TSLA)?'],
#  ['TSLA',
#   'May-03-20',
#   '10:42AM',
#   'Why Tesla Stock Skyrocketed 49.2% in April'],
#  ['TSLA',
#   'May-03-20',
#   '08:18AM',
#   "Benzinga's Bulls And Bears Of The Week: Ford, Gilead, Microsoft, Intel And More"],
#  ['TSLA',
#   'May-03-20',
#   '05:05AM',
#   'Teslas UK Electricity Ambitions Revealed- Report'],
#  ['TSLA',
#   'May-02-20',
#   '11:24PM',
#   'Tesla applies to become UK electricity provider - The Telegraph'],
#  ['TSLA',
#   'May-02-20',
#   '04:06PM',
#   'Tesla applies to become UK electricity provider: The Telegraph'],
#  ['TSLA',
#   'May-02-20',
#   '04:04PM',
#   'Tesla applies to become UK electricity provider - The Telegraph'],
#  ['TSLA',
#   'May-02-20',
#   '03:55PM',
#   "Here's What Warren Buffett Thinks About Tesla And Elon Musk"],
#  ['TSLA',
#   'May-02-20',
#   '03:39PM',
#   'Retiring in 10-20 years? Heres your best approach to stocks right now, says top U.S. financial adviser.'],
#  ['TSLA',
#   'May-02-20',
#   '09:00AM',
#   "Musk caps a strange week by suggesting Tesla's stock price should fall. So it did"],
#  ['TSLA',
#   'May-02-20',
#   '08:55AM',
#   'Elon Musk wipes nearly $15 billion off Teslas valuation by tweeting that shares are too high'],
#  ['TSLA',
#   'May-02-20',
#   '08:16AM',
#   'Stock Market Today With Jim Cramer: Clorox Stock'],
#  ['TSLA',
#   'May-02-20',
#   '07:44AM',
#   "Elon Musk tweet wipes $14bn off Tesla's value"],
#  ['TSLA',
#   'May-02-20',
#   '07:02AM',
#   'Tesla tumbles after Musk tweets stock too high'],
#  ['TSLA',
#   'May-02-20',
#   '02:18AM',
#   'Tesla to extend furlough for some employees by another week - internal email'],
#  ['TSLA',
#   'May-02-20',
#   '02:07AM',
#   'Tesla to extend furlough for some employees by another week: internal email'],
#  ['TSLA',
#   'May-02-20',
#   '02:02AM',
#   'Tesla to extend furlough for some employees by another week - internal email'],
#  ['TSLA',
#   'May-02-20',
#   '01:54AM',
#   'Edited Transcript of TSLA earnings conference call or presentation 29-Apr-20 10:30pm GMT'],
#  ['TSLA',
#   'May-01-20',
#   '08:07PM',
#   'Greenlights Einhorn Exits GM, Doubts Tesla Boards Independence'],
#  ['TSLA',
#   'May-01-20',
#   '05:53PM',
#   'Tesla Falls as Musk Says Stock Too High in 2018-Style Tweets'],
#  ['TSLA',
#   'May-01-20',
#   '04:31PM',
#   'US STOCKS-Wall Street tumbles as renewed tariff threat adds to uncertainties'],
#  ['TSLA',
#   'May-01-20',
#   '04:15PM',
#   'Dow Jones Takes A Beating, But Apple Holds Above Buy Point; Tesla Stock Slammed On Musk Tweet'],
#  ['TSLA',
#   'May-01-20',
#   '04:11PM',
#   'Dow falls 622 points and stock market wipes out weekly gains to start May amid worries about China, Amazon and Apple'],
#  ['TSLA',
#   'May-01-20',
#   '04:08PM',
#   'Stock Market Rally Erases Big Gains On Trump Tariff Threat, Amazon, Tesla, AMD; Microsoft, Google, Facebook, ServiceNow Cheered'],
#  ['TSLA',
#   'May-01-20',
#   '03:13PM',
#   'Tesla Stock Is Falling After Elon Musk Tweeted It Was Too High. Expect It to Fall Further.'],
#  ['TSLA',
#   'May-01-20',
#   '01:30PM',
#   "Elon Musk Says Tesla's Stock Is 'Too High' - Shares Down Sharply"],
#  ['TSLA', 'May-01-20', '01:21PM', 'Why Tesla Stock Fell Friday'],
#  ['TSLA',
#   'May-01-20',
#   '12:33PM',
#   'INVESTIGATION ALERT: The Schall Law Firm Announces it is Investigating Claims Against Tesla, Inc. and Encourages Investors with Losses of $100,000 to Contact the Firm'],
#  ['TSLA',
#   'May-01-20',
#   '12:12PM',
#   'Tesla tumbles after tweet from Musk account saying stock too high'],
#  ['TSLA',
#   'May-01-20',
#   '12:12PM',
#   'Tesla tumbles after Musk tweets stock too high'],
#  ['TSLA',
#   'May-01-20',
#   '12:00PM',
#   'Dow Jones Dives 600 Points On Trump Coronavirus Tariff Threat; Tesla Crashes 12% On Elon Musk Tweet'],
#  ['TSLA',
#   'May-01-20',
#   '11:50AM',
#   'In these confusing times, X-rays of the biggest tech stocks show the strength of the stock market'],
#  ['TSLA',
#   'May-01-20',
#   '10:30AM',
#   'Coronavirus Recession Ends the Golden Age for Tech Workers'],
#  ['TSLA',
#   'May-01-20',
#   '10:18AM',
#   'Tesla stock price target boosted for strong margins'],
#  ['TSLA',
#   'May-01-20',
#   '08:13AM',
#   'Tesla Management Talks Demand, Model Y, and More'],
#  ['TSLA',
#   'May-01-20',
#   '08:09AM',
#   'Dow Jones Futures: Apple, Amazon, Trump Tariff Threat Pressure Coronavirus Stock Market Rally'],
#  ['TSLA',
#   'May-01-20',
#   '06:26AM',
#   'Tesla pulls rabbit out of the hat with surprise profit, and Wall Street applauds it'],
#  ['TSLA',
#   'May-01-20',
#   '02:15AM',
#   "Tesla Shares Decline After Einhorn Publicly Questions Automaker's Accounting Practices"],
#  ['TSLA',
#   'Apr-30-20',
#   '10:58PM',
#   'Stock Market Today With Jim Cramer: Apple, Tesla, Boeing'],
#  ['TSLA',
#   'Apr-30-20',
#   '09:55PM',
#   'RPT-Tesla cuts price for China-made Model 3 cars by 10% to qualify for subsidies'],
#  ['TSLA',
#   'Apr-30-20',
#   '09:44PM',
#   'Tesla cuts price for China-made Model 3 cars by 10% to qualify for subsidies'],
#  ['TSLA',
#   'Apr-30-20',
#   '07:25PM',
#   "Tesla, Inc. -- Moody's announces completion of a periodic review of ratings of Tesla, Inc."],
#  ['TSLA',
#   'Apr-30-20',
#   '07:02PM',
#   "Musk outburst over 'fascist' coronavirus shutdown shows pressure to keep up growth"],
#  ['TSLA',
#   'Apr-30-20',
#   '06:47PM',
#   'Tesla Keeps Beating Expectations. Heres What Wall Street Is Saying About the Stock.'],
#  ['TSLA',
#   'Apr-30-20',
#   '06:39PM',
#   'Elon Musks SpaceX, Jeff Bezos Blue Origin win NASA lunar-lander contracts'],
#  ['TSLA',
#   'Apr-30-20',
#   '05:44PM',
#   'The Dow Fell 288 Points, but Marked the Biggest Monthly Gain in Decades'],
#  ['TSLA',
#   'Apr-30-20',
#   '05:03PM',
#   'Tesla Declines After Einhorn Questions Musks Accounting'],
#  ['TSLA',
#   'Apr-30-20',
#   '03:25PM',
#   'Teslas SEC Filing Is More Fodder for Bulls and Bears. Heres How to Interpret It.'],
#  ['TSLA',
#   'Apr-30-20',
#   '03:01PM',
#   "7 Times Elon Musk Wasn't Afraid To Speak His Mind"],
#  ['TSLA', 'Apr-30-20', '02:40PM', 'Blue Origin, SpaceX Land NASA Deal'],
#  ['TSLA',
#   'Apr-30-20',
#   '02:24PM',
#   "Investor Einhorn tweets at Tesla's Musk asking for more company financials"],
#  ['TSLA',
#   'Apr-30-20',
#   '02:13PM',
#   "Investor Einhorn tweets at Tesla's Musk asking for more company financials"],
#  ['TSLA',
#   'Apr-30-20',
#   '01:31PM',
#   'US STOCKS-Wall St slides on grim jobless data, set for best month in decades'],
#  ['TSLA',
#   'Apr-30-20',
#   '01:30PM',
#   'Dow Jones Dives Over 400 Points On Jobless Claims, Earnings; Apple Hits Buy Point Ahead Of Earnings Results'],
#  ['TSLA',
#   'Apr-30-20',
#   '12:57PM',
#   'Tesla Analysts Break Down Free Cash Flow, Fremont Shutdown, 2020 Expectations After Q1 Print'],
#  ['TSLA',
#   'Apr-30-20',
#   '12:33PM',
#   'Tesla Beats the Street but One 5-Star Analyst Says Sell'],
#  ['TSLA',
#   'Apr-30-20',
#   '11:59AM',
#   'The Zacks Analyst Blog Highlights: Facebook, Microsoft, Tesla, Qualcomm and eBay'],
#  ['TSLA', 'Apr-30-20', '11:24AM', 'Why Tesla Stock Jumped on Thursday'],
#  ['TSLA',
#   'Apr-30-20',
#   '11:15AM',
#   'Tesla Beats Q1 Earnings and Revenue Estimates: ETFs to Soar'],
#  ['TSLA',
#   'Apr-30-20',
#   '11:15AM',
#   'Stock Market News: Why Tesla and Facebook Are Soaring'],
#  ['TSLA',
#   'Apr-30-20',
#   '10:41AM',
#   'US STOCKS-S&P 500, Dow slip after grim jobless claims data'],
#  ['TSLA',
#   'Apr-30-20',
#   '10:33AM',
#   '5 ways to slow global warming that share the burden with the oil patch: McKinsey'],
#  ['TSLA',
#   'Apr-30-20',
#   '09:59AM',
#   'Can The Dow Jones Today Nail Its Best Month In 45 Years? Facebook, Microsoft Rise: Tesla Gaps Above Buy Point'],
#  ['TSLA',
#   'Apr-30-20',
#   '09:56AM',
#   "Tesla's Surprise Q1 Profit: What Wall Street's Saying"],
#  ['TSLA',
#   'Apr-30-20',
#   '09:34AM',
#   'Elon Musk rants against forcibly imprisoning people, but hes got an iffy track record on coronavirus'],
#  ['TSLA',
#   'Apr-30-20',
#   '08:41AM',
#   "Tesla's (TSLA) Q1 Earnings & Revenues Beat Estimates, Up Y/Y"],
#  ['TSLA',
#   'Apr-30-20',
#   '08:40AM',
#   'Wall Street sidesteps Musk lockdown rant as Tesla numbers improve'],
#  ['TSLA',
#   'Apr-30-20',
#   '08:10AM',
#   'Dow Jones Futures: Coronavirus Stock Market Rally Set To Continue For Tech Stocks With These 5 Titans Now In Buy Zones'],
#  ['TSLA',
#   'Apr-30-20',
#   '07:54AM',
#   'Tesla Spikes as Quarterly Profit Takes Investors By Surprise; Musk Says Lockdown is Key Risk to Biz'],
#  ['TSLA',
#   'Apr-30-20',
#   '07:50AM',
#   'US STOCKS-Dow, S&P 500 futures dip at end of strong month; jobless data eyed'],
#  ['TSLA',
#   'Apr-30-20',
#   '07:50AM',
#   'Elon Musk Calls Stay-at-Home Orders Fascist as Tesla Scores Big With Earnings'],
#  ['TSLA',
#   'Apr-30-20',
#   '07:25AM',
#   'Teslas Surprise Profit Fails to Allay Analysts Restart Worries'],
#  ['TSLA',
#   'Apr-30-20',
#   '07:22AM',
#   "Lockdowns are 'fascist', says Musk, but Zuckerberg disagrees"],
#  ['GOOG',
#   'May-05-20',
#   '10:54PM',
#   'Online ad market is recovering from coronavirus shock, but little else is clear'],
#  ['GOOG',
#   'May-05-20',
#   '07:17PM',
#   'Coronavirus Crisis Gives Less Room for Zoom to Boom'],
#  ['GOOG',
#   'May-05-20',
#   '04:58PM',
#   'Pinterest First-Quarter Earnings Miss, Revenue Beat, Stock Down'],
#  ['GOOG',
#   'May-05-20',
#   '02:54PM',
#   'Dont be like Warren Buffett  avoid value stocks for now'],
#  ['GOOG',
#   'May-05-20',
#   '01:39PM',
#   'Splunk Shares Rise on Deal to Become Available on Google Cloud'],
#  ['GOOG',
#   'May-05-20',
#   '12:45PM',
#   'Why Is Everyone Talking About Zoom Video Communications Stock?'],
#  ['GOOG',
#   'May-05-20',
#   '11:36AM',
#   'Here is Why You Should Sell Alphabet Inc. (GOOGL) Now'],
#  ['GOOG',
#   'May-05-20',
#   '10:15AM',
#   'Sell Cloud Stocks Salesforce.com and Workday, Analyst Says'],
#  ['GOOG',
#   'May-05-20',
#   '10:04AM',
#   'Electronic Arts, Boot Barn, Alphabet, Facebook and Twitter highlighted as Zacks Bull and Bear of the Day'],
#  ['GOOG',
#   'May-05-20',
#   '09:48AM',
#   'Why Jim Chanos Bets Against Fraud and China'],
#  ['GOOG',
#   'May-05-20',
#   '09:42AM',
#   "To Escape Lockdown, Don't Be Creepy With Health Data"],
#  ['GOOG',
#   'May-05-20',
#   '09:31AM',
#   'Why Swedens relaxed stance toward coronavirus will be difficult to replicate elsewhere, Goldman Sachs analysts say'],
#  ['GOOG',
#   'May-05-20',
#   '08:47AM',
#   '6 Tech Giants Setting the Northbound Trajectory of Wall Street'],
#  ['GOOG',
#   'May-05-20',
#   '07:46AM',
#   'The Twitter response to J.Crews filing for bankruptcy has been savage  but there is a point being made'],
#  ['GOOG',
#   'May-05-20',
#   '06:09AM',
#   'French Minister Says We Will Remember Apple Privacy Refusal'],
#  ['GOOG',
#   'May-05-20',
#   '06:07AM',
#   'Disneys struggles, videogames success and the potential for fake meat take earnings stage'],
#  ['GOOG',
#   'May-05-20',
#   '06:00AM',
#   'Alphabets Verily Struggles to Live Up to Trumps Hype on Covid Testing'],
#  ['GOOG',
#   'May-04-20',
#   '10:30PM',
#   'Apple And Google Say No To Location Tracking In Coronavirus Contact Tracing Apps'],
#  ['GOOG',
#   'May-04-20',
#   '09:50PM',
#   'YouTube Signs Gamer PewDiePie To Exclusive Streaming Deal'],
#  ['GOOG', 'May-04-20', '05:00PM', 'Lets Make a Deal With Our Robot Overlords'],
#  ['GOOG', 'May-04-20', '04:52PM', 'Why Pinterest Stock Jumped 34% in April'],
#  ['GOOG',
#   'May-04-20',
#   '04:30PM',
#   'Trivago Looks to Reorganize With Significant Job Cuts'],
#  ['GOOG',
#   'May-04-20',
#   '01:23PM',
#   'Post-Earning, Which Is Better: Alphabet or Facebook?'],
#  ['GOOG',
#   'May-04-20',
#   '12:48PM',
#   'Apple, Google ban use of location tracking in contact tracing apps'],
#  ['GOOG',
#   'May-04-20',
#   '12:45PM',
#   '5 Tech Stocks With Enough Cash to Outlast the COVID-19 Crisis'],
#  ['GOOG',
#   'May-04-20',
#   '12:28PM',
#   'AMD Is Quietly Taking Aim at a Big Growth Opportunity'],
#  ['GOOG',
#   'May-04-20',
#   '12:27PM',
#   'Twilight author announces new book, Midnight Sun  and Team Edward loses its mind on Twitter'],
#  ['GOOG',
#   'May-04-20',
#   '12:15PM',
#   'Apple, Google Covid-19 Tool to Be Limited to One App Per Country'],
#  ['GOOG',
#   'May-04-20',
#   '10:45AM',
#   'Could This Behind-the-Scenes Company Be a Market Beater?'],
#  ['GOOG',
#   'May-04-20',
#   '10:00AM',
#   'Google Stock: Is It A Buy Or Better To Wait Amid Covid-19 Lockdown?'],
#  ['GOOG',
#   'May-04-20',
#   '09:33AM',
#   'The Zacks Analyst Blog Highlights: Microsoft, Amazon, Alphabet and Facebook'],
#  ['GOOG',
#   'May-04-20',
#   '09:20AM',
#   'Strong Demand for Games Saves Hasbro From Coronavirus Disaster'],
#  ['GOOG',
#   'May-04-20',
#   '08:48AM',
#   'Look Out Alibaba, JD.com Is Expanding Its Cloud and AI Presence'],
#  ['GOOG', 'May-04-20', '08:25AM', 'Why Alphabet Stock Gained 15.9% in April'],
#  ['GOOG',
#   'May-04-20',
#   '08:00AM',
#   "Is Amazon Stock A Buy Right Now? Here's What Earnings, Charts Show"],
#  ['GOOG',
#   'May-04-20',
#   '07:21AM',
#   'Ranking the FAANG Stocks From Cheapest to Most Expensive'],
#  ['GOOG',
#   'May-04-20',
#   '06:15AM',
#   '2 Stocks That Could Turn Your $1,200 Stimulus Check Into a Fortune'],
#  ['GOOG',
#   'May-04-20',
#   '06:01AM',
#   'A truncated recovery for the economy, but stocks will do better because bigger companies will thrive'],
#  ['GOOG',
#   'May-03-20',
#   '09:15AM',
#   "What Bugs Me Most About Apple's Q2 Services Revenue"],
#  ['GOOG',
#   'May-03-20',
#   '08:45AM',
#   'Google Cloud and YouTube Help Protect Alphabet From a Coronavirus Disaster'],
#  ['GOOG',
#   'May-03-20',
#   '08:16AM',
#   'Could Oracle Solve Zoom Video Communications Biggest Problem?'],
#  ['GOOG',
#   'May-03-20',
#   '08:00AM',
#   'Coronavirus Concerts Are\xa0Music to Our Ears and Eyes'],
#  ['GOOG',
#   'May-02-20',
#   '04:54PM',
#   'Apple Falls After Skipping Forecast for First Time in Years'],
#  ['GOOG',
#   'May-02-20',
#   '10:17AM',
#   'Are investors driven by FOMO, or is a retest of the lows coming? Heres what Wall Street strategists are saying about the stock-market outlook'],
#  ['GOOG',
#   'May-02-20',
#   '09:00AM',
#   "Warren Buffett Says There's No Bubble In FANG Stocks, But He's Still Not Buying"],
#  ['GOOG',
#   'May-02-20',
#   '09:00AM',
#   "Amazon, Microsoft and Google Report Cloud Gains - And Reveal How They're Competing"],
#  ['GOOG',
#   'May-02-20',
#   '08:00AM',
#   'Streaming Services Face an Economic Reckoning After Covid-19'],
#  ['GOOG',
#   'May-01-20',
#   '07:36PM',
#   'Why Big Tech Is Beating the Market. 5 Things We Learned from Earnings.'],
#  ['GOOG',
#   'May-01-20',
#   '04:57PM',
#   'Stocks dive in wake of earnings from tech giants'],
#  ['GOOG', 'May-01-20', '04:57PM', 'Top Strategists on Where to Invest Now'],
#  ['GOOG',
#   'May-01-20',
#   '04:43PM',
#   'Google travel data show lockdown fatigue in U.S., Australia; other countries stay home'],
#  ['GOOG',
#   'May-01-20',
#   '04:08PM',
#   'Stock Market Rally Erases Big Gains On Trump Tariff Threat, Amazon, Tesla, AMD; Microsoft, Google, Facebook, ServiceNow Cheered'],
#  ['GOOG',
#   'May-01-20',
#   '03:51PM',
#   'Google ETFs Gain Despite Mixed Earnings Amid Coronavirus Crisis'],
#  ['GOOG',
#   'May-01-20',
#   '03:18PM',
#   'These Are the Riskiest Stocks Right Now  but They Could Have the Most Reward'],
#  ['GOOG',
#   'May-01-20',
#   '03:17PM',
#   'Oracle Women Score Major Win in Court Battle Over Equal Pay'],
#  ['GOOG',
#   'May-01-20',
#   '02:05PM',
#   "Apple and Google won't solve coronavirus contact tracing. Here's what will"],
#  ['GOOG',
#   'May-01-20',
#   '01:51PM',
#   'Google braved one recession, and Alphabet is more diversified as coronavirus roils rivals'],
#  ['GOOG', 'May-01-20', '12:34PM', 'Tech Giant Posts Amazing Earnings Growth'],
#  ['GOOG', 'May-01-20', '12:16PM', 'Why Alphabet Stock Is Up'],
#  ['GOOG',
#   'May-01-20',
#   '11:50AM',
#   'In these confusing times, X-rays of the biggest tech stocks show the strength of the stock market'],
#  ['GOOG',
#   'May-01-20',
#   '10:30AM',
#   'Coronavirus Recession Ends the Golden Age for Tech Workers'],
#  ['GOOG',
#   'May-01-20',
#   '09:06AM',
#   'Apple earnings dip amid coronavirus pandemic, but investors set to receive billions more'],
#  ['GOOG',
#   'May-01-20',
#   '08:20AM',
#   'The Most Important Takeaway That Drove Both Facebook and Alphabet Stocks Higher After Earnings'],
#  ['GOOG',
#   'May-01-20',
#   '07:27AM',
#   'Why Amazon is expanding Web Services in Africa but still has no e-commerce here'],
#  ['GOOG',
#   'May-01-20',
#   '06:12AM',
#   'For cloud giants, usage soars but tech investment delays hobble revenue growth'],
#  ['GOOG',
#   'May-01-20',
#   '06:04AM',
#   'For cloud giants, usage soars but tech investment delays hobble revenue growth'],
#  ['GOOG',
#   'May-01-20',
#   '05:27AM',
#   'Zoom Corrects Blog Saying It Had 300M Daily Active Users, Admits It Was Wrong'],
#  ['GOOG',
#   'May-01-20',
#   '12:00AM',
#   'Europe split over approach to virus contact tracing apps'],
#  ['GOOG', 'Apr-30-20', '06:43PM', 'Top 10 S&P 500 Stocks by Index Weight'],
#  ['GOOG',
#   'Apr-30-20',
#   '05:28PM',
#   'Twitter Shares Tumble After Virus Spurs Advertising Sales Rout'],
#  ['GOOG',
#   'Apr-30-20',
#   '05:02PM',
#   'Google Faces Calls to Hold off Collecting Ad Dollars From Struggling German Companies'],
#  ['GOOG',
#   'Apr-30-20',
#   '04:28PM',
#   'How to navigate the stock market when all news is great news to care-free investors'],
#  ['GOOG',
#   'Apr-30-20',
#   '03:28PM',
#   "Google, Facebook and Microsoft's Earnings Were Both Encouraging and Cautious"],
#  ['GOOG', 'Apr-30-20', '03:01PM', 'Shares of Alphabet Could Stage a Pullback'],
#  ['GOOG',
#   'Apr-30-20',
#   '02:22PM',
#   'Facebooks Surprisingly Strong Ad Revenue Is Turning Heads on Wall Street'],
#  ['GOOG',
#   'Apr-30-20',
#   '02:18PM',
#   'Digital ad market is avoiding coronavirus disaster, say tech giants'],
#  ['GOOG',
#   'Apr-30-20',
#   '02:06PM',
#   'Apple, Amazon and Gilead take anchor leg of earnings race with a big lead'],
#  ['GOOG',
#   'Apr-30-20',
#   '01:12PM',
#   'Zoom Clarifies It Has 300 Million Participants, Not Users'],
#  ['GOOG',
#   'Apr-30-20',
#   '12:28PM',
#   'Zoom Does Not Have 300 Million Daily Active Users'],
#  ['GOOG',
#   'Apr-30-20',
#   '12:14PM',
#   'Microsoft Teams saw more than 200 million meeting participants in one day in April'],
#  ['GOOG',
#   'Apr-30-20',
#   '11:16AM',
#   "Comcast Tiptoes Into E-Commerce. Here's Why It Matters"],
#  ['GOOG',
#   'Apr-30-20',
#   '11:09AM',
#   'U.K. Lawmakers Question Tech Attempts to Stem Coronavirus Conspiracies'],
#  ['GOOG',
#   'Apr-30-20',
#   '11:05AM',
#   'Google Lobbied by German Travel Companies to Delay Ad Bills'],
#  ['GOOG',
#   'Apr-30-20',
#   '10:59AM',
#   'The Zacks Analyst Blog Highlights: Alphabet, Zoom Video Communications, Oracle, Alibaba and IBM'],
#  ['GOOG',
#   'Apr-30-20',
#   '09:51AM',
#   'Facebook earnings show company is in a better spot than peers during ad slowdown'],
#  ['GOOG', 'Apr-30-20', '09:39AM', 'Microsoft Earnings Defy the Pandemic'],
#  ['GOOG',
#   'Apr-30-20',
#   '09:34AM',
#   'Facebook Follows Google, Signaling Online Ad Pain Set to Worsen'],
#  ['GOOG', 'Apr-30-20', '09:27AM', 'Where will Spotify Be in 5 Years?'],
#  ['GOOG',
#   'Apr-30-20',
#   '08:45AM',
#   'EXCLUSIVE: Emergency Response Tech Firm Carbyne Announces New Board Chairman'],
#  ['GOOG',
#   'Apr-30-20',
#   '08:43AM',
#   'Mega-Cap Tech Players Riding High on Work-From-Home Model'],
#  ['GOOG',
#   'Apr-30-20',
#   '08:42AM',
#   'For Sale: Bankrupt Hospitals in Americas Heartland'],
#  ['GOOG',
#   'Apr-30-20',
#   '08:40AM',
#   "Fandango's Vudu Deal and the Digital Media Marketplace"],
#  ['GOOG',
#   'Apr-30-20',
#   '08:15AM',
#   'Cut us some slack, German travel start-ups tell Google'],
#  ['GOOG',
#   'Apr-30-20',
#   '08:10AM',
#   'Dow Jones Futures: Coronavirus Stock Market Rally Set To Continue For Tech Stocks With These 5 Titans Now In Buy Zones'],
#  ['GOOG', 'Apr-30-20', '05:45AM', 'Facebook: immaculate inception'],
#  ['GOOG',
#   'Apr-30-20',
#   '04:24AM',
#   'The Number One Social Media App Is Missing From Coronavirus Inquiry'],
#  ['GOOG',
#   'Apr-30-20',
#   '04:00AM',
#   'The World Embraces Contact-Tracing Technology to Fight Covid-19'],
#  ['GOOG',
#   'Apr-30-20',
#   '04:00AM',
#   'Apple-Google Virus Combat Plan Hinges on Still-Scarce Testing'],
#  ['GOOG',
#   'Apr-30-20',
#   '03:06AM',
#   'The Lockdown, The Fallout and the RoadMap to Recovery'],
#  ['GOOG',
#   'Apr-29-20',
#   '07:27PM',
#   'Facebook Defies Gravity But Cant Deny Reality']]

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head()
# Out:
#   ticker        date     time  \
# 0   AMZN  2020-05-05  07:17PM
# 1   AMZN  2020-05-05  06:32PM
# 2   AMZN  2020-05-05  06:01PM
# 3   AMZN  2020-05-05  05:34PM
# 4   AMZN  2020-05-05  05:30PM
#
#                                             headline    neg    neu    pos  \
# 0  Coronavirus Crisis Gives Less Room for Zoom to...  0.339  0.661  0.000
# 1  Amazon Worker at Staten Island Warehouse Dies ...  0.000  0.825  0.175
# 2  U.S. Customs Agency Enlists Amazon, Pfizer, 3M...  0.170  0.719  0.111
# 3  Impossible Foods, Beyond Meat see spike in dem...  0.293  0.707  0.000
# 4  Spotify CEO Expects Apple to Further Open Up A...  0.196  0.804  0.000
#
#    compound
# 0   -0.6249
# 1    0.1779
# 2   -0.2263
# 3   -0.6597
# 4   -0.2960

# %%
plt.rcParams['figure.figsize'] = [20, 12]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind='bar')
